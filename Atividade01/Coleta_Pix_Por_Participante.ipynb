# %% [markdown]
# ### Objetivo: Consumir API
#
# Acessando a url https://dadosabertos.bcb.gov.br/dataset/estatisticas-meios-pagamentos vocês terão acesso aos dados fornecidos pelo banco central sobre meios de pagamentos.
# Vocês podem consultar a API para obter a url para requisição dos dados.
#
#
# Determine a url fornecida:

# %%
url = "https://olinda.bcb.gov.br/olinda/servico/Pix_DadosAbertos/versao/v1/odata/ChavesPix(Data=@Data)?@Data='2023-01-01'&$top=50&$format=json&$select=Data,ISPB,Nome,NaturezaUsuario,TipoChave,qtdChaves"

# %% [markdown]
# Importar bibliotecas

# %%
import pandas as pd  #possibilita manipulação e análise de dados
import requests  #possibilita integração com serviços web, solicitações HTTP consumir dados de APIs
import json  #manipular arquivo json

# %% [markdown]
# Criar uma função para obter os dados:

# %%
def requisicao_api(link):
  resposta = requests.get(link)

  if resposta.status_code == 200:      #sucesso na requisição
    dados = resposta.json()
    print('Status Code:', resposta.status_code)
    with open('resultado.json', 'w', encoding='utf-8') as arquivo:   #salvar arquivo json
      json.dump(dados, arquivo, ensure_ascii=False, indent=4)

  else:
    print('Status Code:', resposta.status_code)

# %% [markdown]
# Chamar função passando o link gerado pela interface da API

# %%
requisicao_api(url)
# Out:
# Status Code: 200

# %% [markdown]
# Convertendo em DataFrame

# %%
jsondata = pd.read_json('resultado.json')

# %%
jsondata
# Out:
#                                        @odata.context  \
# 0   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 1   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 2   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 3   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 4   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 5   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 6   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 7   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 8   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 9   https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 10  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 11  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 12  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 13  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 14  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 15  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 16  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 17  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 18  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 19  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 20  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 21  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 22  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 23  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 24  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 25  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 26  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 27  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 28  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 29  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 30  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 31  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 32  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 33  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 34  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 35  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 36  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 37  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 38  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 39  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 40  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 41  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 42  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 43  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 44  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 45  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 46  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 47  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 48  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 49  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
#
#                                                 value
# 0   {'Data': '2025-06-30', 'ISPB': '67960229', 'No...
# 1   {'Data': '2024-06-30', 'ISPB': '07564184', 'No...
# 2   {'Data': '2023-02-28', 'ISPB': '07440317', 'No...
# 3   {'Data': '2025-01-31', 'ISPB': '33641877', 'No...
# 4   {'Data': '2024-10-31', 'ISPB': '07097064', 'No...
# 5   {'Data': '2024-12-31', 'ISPB': '70431630', 'No...
# 6   {'Data': '2024-12-31', 'ISPB': '92934215', 'No...
# 7   {'Data': '2023-12-31', 'ISPB': '73647935', 'No...
# 8   {'Data': '2024-05-31', 'ISPB': '09639338', 'No...
# 9   {'Data': '2024-10-31', 'ISPB': '05428587', 'No...
# 10  {'Data': '2023-08-31', 'ISPB': '22896431', 'No...
# 11  {'Data': '2025-06-30', 'ISPB': '30507541', 'No...
# 12  {'Data': '2023-01-31', 'ISPB': '11760553', 'No...
# 13  {'Data': '2023-10-31', 'ISPB': '33172537', 'No...
# 14  {'Data': '2024-06-30', 'ISPB': '71432926', 'No...
# 15  {'Data': '2024-03-31', 'ISPB': '09515813', 'No...
# 16  {'Data': '2024-01-31', 'ISPB': '87733077', 'No...
# 17  {'Data': '2023-02-28', 'ISPB': '01760242', 'No...
# 18  {'Data': '2024-03-31', 'ISPB': '01864151', 'No...
# 19  {'Data': '2024-07-31', 'ISPB': '30385259', 'No...
# 20  {'Data': '2024-07-31', 'ISPB': '00707903', 'No...
# 21  {'Data': '2025-07-31', 'ISPB': '25387671', 'No...
# 22  {'Data': '2023-02-28', 'ISPB': '08357240', 'No...
# 23  {'Data': '2025-06-30', 'ISPB': '27842177', 'No...
# 24  {'Data': '2024-06-30', 'ISPB': '04237413', 'No...
# 25  {'Data': '2025-07-31', 'ISPB': '40557732', 'No...
# 26  {'Data': '2023-03-31', 'ISPB': '07206072', 'No...
# 27  {'Data': '2024-11-30', 'ISPB': '04694278', 'No...
# 28  {'Data': '2024-06-30', 'ISPB': '06332931', 'No...
# 29  {'Data': '2023-05-31', 'ISPB': '40867163', 'No...
# 30  {'Data': '2024-10-31', 'ISPB': '07679404', 'No...
# 31  {'Data': '2025-02-28', 'ISPB': '95213211', 'No...
# 32  {'Data': '2024-09-30', 'ISPB': '09639338', 'No...
# 33  {'Data': '2023-09-30', 'ISPB': '05888589', 'No...
# 34  {'Data': '2024-03-31', 'ISPB': '81723108', 'No...
# 35  {'Data': '2023-04-30', 'ISPB': '41805003', 'No...
# 36  {'Data': '2024-02-29', 'ISPB': '26960328', 'No...
# 37  {'Data': '2025-03-31', 'ISPB': '92702067', 'No...
# 38  {'Data': '2025-06-30', 'ISPB': '35534511', 'No...
# 39  {'Data': '2023-12-31', 'ISPB': '78157146', 'No...
# 40  {'Data': '2023-05-31', 'ISPB': '42873828', 'No...
# 41  {'Data': '2023-12-31', 'ISPB': '89280960', 'No...
# 42  {'Data': '2023-06-30', 'ISPB': '71328769', 'No...
# 43  {'Data': '2025-07-31', 'ISPB': '26960328', 'No...
# 44  {'Data': '2024-12-31', 'ISPB': '05276770', 'No...
# 45  {'Data': '2024-10-31', 'ISPB': '37511258', 'No...
# 46  {'Data': '2023-08-31', 'ISPB': '00804046', 'No...
# 47  {'Data': '2023-10-31', 'ISPB': '02335109', 'No...
# 48  {'Data': '2024-09-30', 'ISPB': '03528402', 'No...
# 49  {'Data': '2023-05-31', 'ISPB': '02015588', 'No...

# %%
data = jsondata['value']

# %% [markdown]
# ```
# data = [
#     {"id": 1, "nome": "Maria", "endereco": {"cidade": "SP", "rua": "Paulista"}},
#     {"id": 2, "nome": "João", "endereco": {"cidade": "RJ", "rua": "Copacabana"}}
# ]
#
# dados_df = pd.json_normalize(data)
# ```
#
# id    |    nome     |   endereco.cidade     |     endereco.rua
#
# 1 | Maria    |          SP   |  Paulista
#
# 2  | João       |       RJ  | Copacabana

# %%
dados_df = pd.json_normalize(data)

# %% [markdown]
# Exibindo os primeiros valores do Dataframe

# %%
dados_df.head()
# Out:
#          Data      ISPB                   Nome NaturezaUsuario  TipoChave  \
# 0  2025-06-30  67960229          CC CREDIGUAÇU              PF    Celular
# 1  2024-06-30  07564184    COOP ASCOOB SERTÕES              PF    Celular
# 2  2023-02-28  07440317      CC SICOOB CREDMED              PJ    Celular
# 3  2025-01-31  33641877             EQUIS BANK              PJ     e-mail
# 4  2024-10-31  07097064  COOP SICOOB CONFIANÇA              PF  Aleatória
#
#    qtdChaves
# 0       6255
# 1          6
# 2          1
# 3          4
# 4       2427

# %%
dados_df.to_csv("dados/pix_participantes.csv", index=False, encoding="utf-8")
